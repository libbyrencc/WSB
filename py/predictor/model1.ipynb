# %%
import alpaca_backtrader_api
from alpaca_trade_api.rest import REST, TimeFrame
import backtrader as bt
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import utils, datasets, layers, models
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM

# %%
# the entry of our trading 
ALPACA_API_KEY ="PK8SSSXD3FX164IYREJ5"
ALPACA_SECRET_KEY ="NPKEgtQyt3fsRodbOqn4d46V19XI5W9S8Cv64dDT"
# do the paper test
ALPACA_PAPER = True

# %%
# access our alpaca platform
api = REST(ALPACA_API_KEY,
           ALPACA_SECRET_KEY,
           'https://paper-api.alpaca.amrkets'
          )

# %%
# obtain 2-year data from a specific stock and clean it
symbol = 'SPY'
bar = api.get_barset(symbol, 'day', limit=730)

c = []
t = []
idx = []

for i in range(len(bar[symbol])):
    temp_c = c.append(bar[symbol][i].c) 
    temp_t = t.append(bar[symbol][i].t)
    temp_idx = idx.append(i)
    i = i + 1

df_bar_t = pd.DataFrame(t, idx,columns = ['Date'])
df_bar_c = pd.DataFrame(c, idx, columns = ['Close'])

new_data = pd.merge(df_bar_t,df_bar_c, left_index = True, right_index = True)
new_data
# Out:
#                          Date   Close
# 0   2019-01-14 00:00:00-05:00  257.69
# 1   2019-01-15 00:00:00-05:00  260.21
# 2   2019-01-16 00:00:00-05:00  260.94
# 3   2019-01-17 00:00:00-05:00  262.88
# 4   2019-01-18 00:00:00-05:00  266.16
# ..                        ...     ...
# 725 2021-11-29 00:00:00-05:00  464.63
# 726 2021-11-30 00:00:00-05:00  455.78
# 727 2021-12-01 00:00:00-05:00  450.53
# 728 2021-12-02 00:00:00-05:00  457.38
# 729 2021-12-03 00:00:00-05:00  453.43
#
# [730 rows x 2 columns]

# %%
# create a new set of data manually
def add_nextdate(data):
    date=data.iloc[-1][0]
    price_fake= data.iloc[-1][1]
    date_n=date+timedelta(days=1)
    data.loc[len(data.index)]=[date_n,price_fake]
    print(data)
add_nextdate(new_data)
# Out:
#                          Date   Close
# 0   2019-01-14 00:00:00-05:00  257.69
# 1   2019-01-15 00:00:00-05:00  260.21
# 2   2019-01-16 00:00:00-05:00  260.94
# 3   2019-01-17 00:00:00-05:00  262.88
# 4   2019-01-18 00:00:00-05:00  266.16
# ..                        ...     ...
# 726 2021-11-30 00:00:00-05:00  455.78
# 727 2021-12-01 00:00:00-05:00  450.53
# 728 2021-12-02 00:00:00-05:00  457.38
# 729 2021-12-03 00:00:00-05:00  453.43
# 730 2021-12-04 00:00:00-05:00  453.43
#
# [731 rows x 2 columns]

# %% [markdown]
# We now are going to use Long Short Term Memory (LSTM) as our netural network to train our model.
#
# LSTMs are widely used for sequence prediction problems and have proven to be extremely effective. The reason they work so well is because LSTM is able to store past information that is important, and forget the information that is not. LSTM has three gates:
#
# `The input gate`: The input gate adds information to the cell state
#
# `The forget gate`: It removes the information that is no longer required by the model
#
# `The output gate`: Output Gate at LSTM selects the information to be shown as output
#
# reference: https://en.wikipedia.org/wiki/Long_short-term_memory

# %%
#transform index
new_data.index = new_data.Date
new_data.drop('Date', axis=1, inplace=True)

 
#creating train and vaild sets
dataset = new_data.values
 
train = dataset[0:511,:]
valid = dataset[511:,:]
 
#converting dataset into X_train and y_train
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(dataset)

# training model 
X_train, y_train = [], []
for i in range(60,len(train)):
    X_train.append(scaled_data[i-60:i,0])
    y_train.append(scaled_data[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)
 
X_train = np.reshape(X_train, (X_train.shape[0],X_train.shape[1],1))
 
# add LSTM network
model = Sequential([
    layers.LSTM(units = 70, return_sequences = True, input_shape = (X_train.shape[1], 1)), 
    layers.Dropout(0.3),
    layers.LSTM(units = 50),
    layers.Dropout(0.2),
    layers.Dense(units = 1)
    ])

#compile and fit our model
model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(X_train, y_train, epochs=15, batch_size=32, verbose=2)
 
#using past 60 sets of data from the train data
inputs = new_data[len(new_data) - len(valid) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = scaler.transform(inputs)

X_test = []
for i in range(60,inputs.shape[0]):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))

# making predictions on the test data
closing_price = model.predict(X_test)
closing_price = scaler.inverse_transform(closing_price)
# Out:
# Epoch 1/15
# 15/15 - 5s - loss: 0.0287 - 5s/epoch - 322ms/step
# Epoch 2/15
# 15/15 - 1s - loss: 0.0069 - 913ms/epoch - 61ms/step
# Epoch 3/15
# 15/15 - 1s - loss: 0.0046 - 729ms/epoch - 49ms/step
# Epoch 4/15
# 15/15 - 1s - loss: 0.0040 - 745ms/epoch - 50ms/step
# Epoch 5/15
# 15/15 - 1s - loss: 0.0034 - 1s/epoch - 89ms/step
# Epoch 6/15
# 15/15 - 1s - loss: 0.0027 - 902ms/epoch - 60ms/step
# Epoch 7/15
# 15/15 - 1s - loss: 0.0032 - 765ms/epoch - 51ms/step
# Epoch 8/15
# 15/15 - 1s - loss: 0.0030 - 721ms/epoch - 48ms/step
# Epoch 9/15
# 15/15 - 1s - loss: 0.0028 - 1s/epoch - 72ms/step
# Epoch 10/15
# 15/15 - 1s - loss: 0.0025 - 1s/epoch - 77ms/step
# Epoch 11/15
# 15/15 - 1s - loss: 0.0025 - 723ms/epoch - 48ms/step
# Epoch 12/15
# 15/15 - 1s - loss: 0.0028 - 728ms/epoch - 49ms/step
# Epoch 13/15
# 15/15 - 1s - loss: 0.0028 - 716ms/epoch - 48ms/step
# Epoch 14/15
# 15/15 - 1s - loss: 0.0024 - 707ms/epoch - 47ms/step
# Epoch 15/15
# 15/15 - 1s - loss: 0.0025 - 728ms/epoch - 49ms/step

# %%
# error calculation 
rms = np.sqrt(np.mean(np.power((valid-closing_price),2)))
rms
# Out:
# 8.578207488715186

# %%
# Visualizing the prediction

# Take 70% of the whole data as our train data
train = new_data[:511]
# The rest is our vaild data
valid = new_data[511:]
valid['Predictions'] = closing_price
plt.rcParams["figure.figsize"] = [30, 13]
plt.rcParams["figure.autolayout"] = True
plt.plot(train['Close'], label = "Real closing price")
plt.plot(valid[['Close']], label = "Vaild closing price")
plt.plot(valid[['Predictions']], label = "Predicted closing price")
plt.legend()
# Out:
# /var/folders/63/s_dlyjvx16z1cy0sqjdr_z840000gn/T/ipykernel_2609/277148677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = closing_price

# %%
# predict how the closing price changes tomorrow
def nextday_predict(data):
    change = data.iloc[-1][0]-data.iloc[-1][1]
    return f"Tomorrow's closing price has changed by {change} compared with today"

change = nextday_predict(valid)
print(change)
# Out:
# Tomorrow's closing price has changed by -18.596794433593743 compared with today
